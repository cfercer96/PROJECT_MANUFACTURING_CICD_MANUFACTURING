# %% [markdown]
# #WIDGETS

# %%
dbutils.widgets.removeAll();

# %%
# %sql
create widget text storageName default "storageaccountcf9603";

# %% [markdown]
# # External location

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS `exlt-data`
URL 'abfss://data@storageaccountcf9603.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL sc_adls_project)
COMMENT 'Ubicación de catalogos y tablas'

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS `exlt-raw`
URL 'abfss://raw@${storageName}.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL sc_adls_project)
COMMENT 'Ubicación de datasets csv'

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS `ext-bronze`
URL 'abfss://bronze@${storageName}.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL sc_adls_project)
COMMENT 'Ubicación externa para tablas bronze'

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS `ext-silver`
URL 'abfss://silver@${storageName}.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL sc_adls_project)
COMMENT 'Ubicación externa para tablas silver'

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS `ext-gold`
URL 'abfss://gold@${storageName}.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL sc_adls_project)
COMMENT 'Ubicación externa para tablas golden'

# %% [markdown]
# #CATALOGS

# %%
# %sql

CREATE CATALOG IF NOT EXISTS catalog_project
MANAGED LOCATION 'abfss://data@${storageName}.dfs.core.windows.net/'

# %% [markdown]
# #SCHEMAS

# %%
# %sql
-- 2) Schemas por capa
CREATE SCHEMA IF NOT EXISTS catalog_project.bronze;
CREATE SCHEMA IF NOT EXISTS catalog_project.silver;
CREATE SCHEMA IF NOT EXISTS catalog_project.gold;

# %%
# %sql
SHOW CATALOGS;
